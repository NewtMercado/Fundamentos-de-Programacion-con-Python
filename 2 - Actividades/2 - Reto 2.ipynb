# %% [markdown]
# #Reto 2

# %% [markdown]
# Enunciado
# Calculo del Multas.
#
# Debido a la alta accidentalidad presentada en el último año en las carreteras del territorio nacional, el Gobierno Colombiano ha decidido implementar controles que permitan sancionara a los conductores que no respeten los límites de velocidad establecidos por los organismos de control. Con este fin, el Ministerio de Transporte ha decidido implementar radares de tramo en las carreteras con mayores índices de accidentalidad en el país.
#
# Los radares de tramo funcionan colocando dos cámaras en dos puntos alejados de una carretera con el fin de comprobar cuánto tiempo tarda un conductor recorrer dicho tramo. Estos radares no miden la velocidad de paso, sino el tiempo de paso representado como la velocidad media de un conductor en un trayecto con una longitud determinada.
#
# La interpretación del funcionamiento de los radares es simple: si colocamos las cámaras separadas 10 Km en un tramo cuya velocidad máxima es de 110 Km/h y un conductor tarda 5 minutos en ser visto por la segunda cámara, sabremos que su velocidad media ha sido de 120 Km/h, y por tanto, en algún sitio ha superado la velocidad permitida.
#
# Usted hace parte del equipo de desarrollo encargado de construir el software que procesará los datos registrados por las cámaras.Su misión es crear un programa en Python que permita saber si un conductor debe ser multado o no.

# %%
# borrador del ejercicio :

# programa 1: (tipo 1)

# entrada de datos:
print( "distancia en metros que separa dos cámaras, espacio, La velocidad máxima permitida en ese tramo en (Km/h), espacio, El tiempo en segundos que tarda el conductor en recorrer el trayecto")
Distancia, VelocidadPermitida, Tiempo = input().split()

# proceso y salida de datos:
  #conversion de datos a valores numericos:
DistanciaCamaras = int(Distancia)
VelocidadPermitida = int(VelocidadPermitida)
TiempoConductor = int(Tiempo)
  #conversion de datos km a m y de H a s:
DistanciaCamaras= DistanciaCamaras *(1 / 1000)
TiempoConductor= TiempoConductor *(1 / 3600)
  #Velocidad del conductor:
VelocidadConductor = DistanciaCamaras / TiempoConductor
print(VelocidadConductor)
  #20% de la velocidad Permitida:
VelocidadExcedidaEn20 = VelocidadPermitida + (VelocidadPermitida *(20 /100))
print(VelocidadExcedidaEn20)

if VelocidadConductor <= VelocidadPermitida:
  print("OK")
elif VelocidadConductor < VelocidadExcedidaEn20:
  print("MULTA")
elif VelocidadPermitida < 0 or TiempoConductor < 0 :
  print("ERROR")
elif VelocidadConductor >= VelocidadExcedidaEn20:
  print("CURSO SENSIBILIZACION")
# Out:
# distancia en metros que separa dos cámaras, espacio, La velocidad máxima permitida en ese tramo en (Km/h), espacio, El tiempo en segundos que tarda el conductor en recorrer el trayecto
# 12000 -100 359
# 120.33426183844011
# -120.0
# ERROR

# %%
# borrador del ejercicio :

# programa 1: (tipo 1)

# entrada de datos:
print( "distancia en metros que separa dos cámaras, espacio, La velocidad máxima permitida en ese tramo en (Km/h), espacio, El tiempo en segundos que tarda el conductor en recorrer el trayecto")
Distancia, VelocidadPermitida, Tiempo = input().split()

# proceso y salida de datos:
  #conversion de datos a valores numericos:
DistanciaCamaras = int(Distancia)
VelocidadPermitida = int(VelocidadPermitida)
TiempoConductor = int(Tiempo)
  #conversion de datos km a m y de H a s:
DistanciaCamaras= DistanciaCamaras *(1 / 1000)
TiempoConductor= TiempoConductor *(1 / 3600)
  #Velocidad del conductor:
VelocidadConductor = DistanciaCamaras / TiempoConductor
print(VelocidadConductor)
  #20% de la velocidad Permitida:
VelocidadExcedidaEn20 = VelocidadPermitida + (VelocidadPermitida *(20 /100))
print(VelocidadExcedidaEn20)

if VelocidadConductor <= VelocidadPermitida:
  print("OK")
elif VelocidadConductor < VelocidadExcedidaEn20:
  print("MULTA")
elif VelocidadConductor>0 and VelocidadExcedidaEn20 > 0 and VelocidadConductor >= VelocidadExcedidaEn20:
  print("CURSO SENSIBILIZACION")
elif VelocidadPermitida < 0 or TiempoConductor < 0 :
  print("ERROR")
# Out:
# distancia en metros que separa dos cámaras, espacio, La velocidad máxima permitida en ese tramo en (Km/h), espacio, El tiempo en segundos que tarda el conductor en recorrer el trayecto
# 12000 -100 359
# 120.33426183844011
# -120.0
# ERROR

# %%
Distancia, VelocidadPermitida, Tiempo = input().split()

DistanciaCamaras = int(Distancia)
VelocidadPermitida = int(VelocidadPermitida)
TiempoConductor = int(Tiempo)
  
DistanciaCamaras= DistanciaCamaras *(1 / 1000)
TiempoConductor= TiempoConductor *(1 / 3600)

VelocidadConductor = DistanciaCamaras / TiempoConductor
VelocidadExcedidaEn20 = VelocidadPermitida + (VelocidadPermitida *(20 /100))

if VelocidadConductor <= VelocidadPermitida:
  print("OK")
elif VelocidadConductor < VelocidadExcedidaEn20:
  print("MULTA")
elif VelocidadConductor>0 and VelocidadExcedidaEn20 > 0 and VelocidadConductor >= VelocidadExcedidaEn20:
  print("CURSO SENSIBILIZACION")
elif VelocidadPermitida < 0 or TiempoConductor < 0 :
  print("ERROR")
# Out:
# 12000 -100 359
# CURSO SENSIBILIZACION
