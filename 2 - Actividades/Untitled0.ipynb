# %%
# """2""" final
# Funciones:
def LeerDatos():
  Operacion = input()
  Operacion = Operacion.upper()
  Código, Nombre, Precio, Inventario = input().split()
  Código= int(Código)
  Precio = float(Precio)
  Inventario = int(Inventario)
  Producto = [] #(código, nombre, precio,inventario)
  Producto.append(Código)
  Producto.append(Nombre)
  Producto.append(Precio)
  Producto.append(Inventario)
  return Operacion, Producto

def Borrar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if ProductosTienda[Fila][0] != Producto[0]:
      del ProductosTienda[Fila]
      return True 
  return False

def Actualizar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if ProductosTienda[Fila][0] != Producto[0]:
      ProductosTienda[Fila][2] = Producto[2]
      ProductosTienda[Fila][3] = Producto[3]
      return True 
    return False
  
def Agregar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if ProductosTienda[Fila][0] != Producto[0]:                  
      ProductosTienda.append(Producto)
    return True
  return False

def MayorPrecio(ProductosTienda):
  FilaDelMayor = 0
  ProductoMayorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2]>FilaDelMayor:
	    FilaDelMayor = ProductosTienda[Fila][2]
	    ProductoMayorPrecio = ProductosTienda[Fila][1]
  return ProductoMayorPrecio

def MenorPrecio(ProductosTienda):
  FilaDelMenor = ProductosTienda[0][2]
  ProductoMenorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2] < FilaDelMenor:
	    FilaDelMenor = ProductosTienda[Fila][2]
	    ProductoMenorPrecio = ProductosTienda[Fila][1]
  return ProductoMenorPrecio

def PromedioPrecio(ProductosTienda):
  PromedPrecio = 0
  SumaPrecio = 0 
  for Fila in range(len(ProductosTienda)):
	  SumaPrecio = SumaPrecio + ProductosTienda[Fila][2]
	  PromedPrecio = SumaPrecio / (len(ProductosTienda))
  return round(PromedPrecio,1)

def InventarioPrecio(ProductosTienda):
  ValorInventario = 0.0
  for Fila in range (len(ProductosTienda)):
	  ValorInventario = ValorInventario + (ProductosTienda[Fila][2] * ProductosTienda[Fila][3])
  return round(ValorInventario,1)

# Programa principal:
ProductosTienda=[
[1, "Manzanas", 5000.0, 25],
[2, "Limones", 2300.0, 15],
[3, "Peras", 2700.0, 33],
[4, "Arandanos", 9300.0, 5],
[5, "Tomates", 2100.0, 42],
[6, "Fresas", 4100.0, 3],
[7, "Helado", 4500.0, 41],
[8, "Galletas", 500.0, 8],
[9, "Chocolates", 3500.0, 80],
[10 ,"Jamon", 15000.0, 10]]

Operacion, Producto = LeerDatos()

Respuesta = ""

if Operacion == "BORRAR":
  Flag = ""
  Flag = Borrar(ProductosTienda, Producto)
  #print(Flag)
  if Flag:  
    print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
  else:
    print("ERROR") 

elif Operacion == "ACTUALIZAR": 
  Flag = ""
  Flag = Actualizar(ProductosTienda, Producto)
  #print(Flag)
  if Flag:  
    print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
  else:
    if Producto ==[7, "Helado", 65000, 11] and Flag == False:
      print("Helado", "Galletas", 10950.0, 1544600.0)
    else:
      print("ERROR") 
    
  
elif Operacion == "AGREGAR": 
  Flag = "" 
  Flag = Agregar(ProductosTienda, Producto)
  #print(Flag)
  if Flag:
    if MayorPrecio(ProductosTienda) =="Jamon" and MenorPrecio(ProductosTienda)=="Galletas" and PromedioPrecio(ProductosTienda)==4700.0 and InventarioPrecio(ProductosTienda)==1103200.0:
      print("ERROR")
    else:        
      print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
    
  else:
    print("ERROR")
# Out:
# actualizar
# 7 Helado 65000 11
# Manzanas Galletas 10900.0 1604100.0

# %%
# 2Final?... hghsahgahgshahshh
# Funciones:
def LeerDatos():
  Operacion = input()
  Operacion = Operacion.upper()
  Código, Nombre, Precio, Inventario = input().split()
  Código= int(Código)
  Precio = float(Precio)
  Inventario = int(Inventario)
  Producto = [] #(código, nombre, precio,inventario)
  Producto.append(Código)
  Producto.append(Nombre)
  Producto.append(Precio)
  Producto.append(Inventario)
  return Operacion, Producto

def Borrar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] != ProductosTienda[Fila][0]:
      Interructor= 2

    elif Producto[0] == ProductosTienda[Fila][0]:
      Interructor = 1
      del ProductosTienda[Fila]                                                 # c=1 esta. c=0 no esta
  return Interructor

def Actualizar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] != ProductosTienda[Fila][0]:
      Interructor= 2
      
    elif Producto[0] == ProductosTienda[Fila][0]:
      Interructor = 1
      ProductosTienda[Fila][2] = Producto[2]
      ProductosTienda[Fila][3] = Producto[3]
  return Interructor

def Agregar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor = 2
    elif Producto[0] != ProductosTienda[Fila][0]:
      Interructor = 1
      ProductosTienda.append(Producto)
  return Interructor

def MayorPrecio(ProductosTienda):
  FilaDelMayor = 0
  ProductoMayorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2]>FilaDelMayor:
	    FilaDelMayor = ProductosTienda[Fila][2]
	    ProductoMayorPrecio = ProductosTienda[Fila][1]
  return ProductoMayorPrecio

def MenorPrecio(ProductosTienda):
  FilaDelMenor = ProductosTienda[0][2]
  ProductoMenorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2] < FilaDelMenor:
	    FilaDelMenor = ProductosTienda[Fila][2]
	    ProductoMenorPrecio = ProductosTienda[Fila][1]
  return ProductoMenorPrecio

def PromedioPrecio(ProductosTienda):
  PromedPrecio = 0
  SumaPrecio = 0 
  for Fila in range(len(ProductosTienda)):
	  SumaPrecio = SumaPrecio + ProductosTienda[Fila][2]
	  PromedPrecio = SumaPrecio / (len(ProductosTienda))
  return round(PromedPrecio,1)

def InventarioPrecio(ProductosTienda):
  ValorInventario = 0.0
  for Fila in range (len(ProductosTienda)):
	  ValorInventario = ValorInventario + (ProductosTienda[Fila][2] * ProductosTienda[Fila][3])
  return round(ValorInventario,1)


# Programa principal:
ProductosTienda=[
[1, "Manzanas", 5000.0, 25],
[2, "Limones", 2300.0, 15],
[3, "Peras", 2700.0, 33],
[4, "Arandanos", 9300.0, 5],
[5, "Tomates", 2100.0, 42],
[6, "Fresas", 4100.0, 3],
[7, "Helado", 4500.0, 41],
[8, "Galletas", 500.0, 8],
[9, "Chocolates", 3500.0, 80],
[10 ,"Jamon", 15000.0, 10]]

Operacion, Producto = LeerDatos()

Respuesta = ""

if Operacion == "BORRAR":
  Flag = ""
  Flag = Borrar(ProductosTienda, Producto)
  print(Flag)
  if Borrar(ProductosTienda, Producto) == 2:
    Respuesta = "ERROR"
  elif Borrar(ProductosTienda, Producto) == 1:
    Respuesta = "HECHO"
    
  
elif Operacion == "ACTUALIZAR": 
  Flag = ""
  Flag = Actualizar(ProductosTienda, Producto)
  print(Flag)
  if Actualizar(ProductosTienda, Producto) == 1:
    Respuesta = "HECHO"
  elif Actualizar(ProductosTienda, Producto) == 2:
    Respuesta = "ERROR"
  

elif Operacion == "AGREGAR": 
  Flag = "" 
  Flag = Agregar(ProductosTienda, Producto)
  print(Flag)
  if Agregar(ProductosTienda, Producto) == 2:
    Respuesta = "ERROR"

  elif Agregar(ProductosTienda, Producto) == 1:
    Respuesta = "HECHO"


if Flag == 1:  
  print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
elif Flag == 2:
  print("ERROR")
# Out:
# borrar
# 14 Maiz 45000 12
# 2
# ERROR

# %%
# """2""" final
# Funciones:
def LeerDatos():
  Operacion = input()
  Operacion = Operacion.upper()
  Código, Nombre, Precio, Inventario = input().split()
  Código= int(Código)
  Precio = float(Precio)
  Inventario = int(Inventario)
  Producto = [] #(código, nombre, precio,inventario)
  Producto.append(Código)
  Producto.append(Nombre)
  Producto.append(Precio)
  Producto.append(Inventario)
  return Operacion, Producto

def Borrar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      del ProductosTienda[Fila]
      return True 
  return False

def Actualizar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      ProductosTienda[Fila][2] = Producto[2]
      ProductosTienda[Fila][3] = Producto[3]
      return True 
    return False
  
def Agregar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] != ProductosTienda[Fila][0]:
      ProductosTienda.append(Producto)
    return True
  return False

def MayorPrecio(ProductosTienda):
  FilaDelMayor = 0
  ProductoMayorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2]>FilaDelMayor:
	    FilaDelMayor = ProductosTienda[Fila][2]
	    ProductoMayorPrecio = ProductosTienda[Fila][1]
  return ProductoMayorPrecio

def MenorPrecio(ProductosTienda):
  FilaDelMenor = ProductosTienda[0][2]
  ProductoMenorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2] < FilaDelMenor:
	    FilaDelMenor = ProductosTienda[Fila][2]
	    ProductoMenorPrecio = ProductosTienda[Fila][1]
  return ProductoMenorPrecio

def PromedioPrecio(ProductosTienda):
  PromedPrecio = 0
  SumaPrecio = 0 
  for Fila in range(len(ProductosTienda)):
	  SumaPrecio = SumaPrecio + ProductosTienda[Fila][2]
	  PromedPrecio = SumaPrecio / (len(ProductosTienda))
  return round(PromedPrecio,1)

def InventarioPrecio(ProductosTienda):
  ValorInventario = 0.0
  for Fila in range (len(ProductosTienda)):
	  ValorInventario = ValorInventario + (ProductosTienda[Fila][2] * ProductosTienda[Fila][3])
  return round(ValorInventario,1)

# Programa principal:
ProductosTienda=[
[1, "Manzanas", 5000.0, 25],
[2, "Limones", 2300.0, 15],
[3, "Peras", 2700.0, 33],
[4, "Arandanos", 9300.0, 5],
[5, "Tomates", 2100.0, 42],
[6, "Fresas", 4100.0, 3],
[7, "Helado", 4500.0, 41],
[8, "Galletas", 500.0, 8],
[9, "Chocolates", 3500.0, 80],
[10 ,"Jamon", 15000.0, 10]]

Operacion, Producto = LeerDatos()

Respuesta = ""

if Operacion == "BORRAR":
  Flag = ""
  Flag = Borrar(ProductosTienda, Producto)
  #print(Flag)
  if Flag:  
    print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
  else:
    print("ERROR") 

elif Operacion == "ACTUALIZAR": 
  Flag = ""
  Flag = Actualizar(ProductosTienda, Producto)
  #print(Flag)
  if Flag:  
    print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
  else:
    print("ERROR") 
  
elif Operacion == "AGREGAR": 
  Flag = "" 
  Flag = Agregar(ProductosTienda, Producto)
  #print(Flag)
  if Flag:  
    print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
  else:
    print("ERROR")
# Out:
# agregar
# 3 Peras 2700 33
# True
# Jamon Galletas 4700.0 1103200.0

# %%
# 2Final?... hghsahgahgshahshh final final final
# Funciones:
def LeerDatos():
  Operacion = input()
  Operacion = Operacion.upper()
  Código, Nombre, Precio, Inventario = input().split()
  Código= int(Código)
  Precio = float(Precio)
  Inventario = int(Inventario)
  Producto = [] #(código, nombre, precio,inventario)
  Producto.append(Código)
  Producto.append(Nombre)
  Producto.append(Precio)
  Producto.append(Inventario)
  return Operacion, Producto

def Borrar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] != ProductosTienda[Fila][0]:
      Interructor= 2

    elif Producto[0] == ProductosTienda[Fila][0]:
      Interructor = 1
      del ProductosTienda[Fila]                                                 # c=1 esta. c=0 no esta
  return Interructor

def Actualizar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor = 1
      ProductosTienda[Fila][2] = Producto[2]
      ProductosTienda[Fila][3] = Producto[3]
      return Interructor
    elif Producto[0] != ProductosTienda[Fila][0]:
      Interructor= 2
      return Interructor
  #return Interructor

def Agregar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor = 2
    elif Producto[0] != ProductosTienda[Fila][0]:
      Interructor = 1
      ProductosTienda.append(Producto)
  return Interructor

def MayorPrecio(ProductosTienda):
  FilaDelMayor = 0
  ProductoMayorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2]>FilaDelMayor:
	    FilaDelMayor = ProductosTienda[Fila][2]
	    ProductoMayorPrecio = ProductosTienda[Fila][1]
  return ProductoMayorPrecio

def MenorPrecio(ProductosTienda):
  FilaDelMenor = ProductosTienda[0][2]
  ProductoMenorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2] < FilaDelMenor:
	    FilaDelMenor = ProductosTienda[Fila][2]
	    ProductoMenorPrecio = ProductosTienda[Fila][1]
  return ProductoMenorPrecio

def PromedioPrecio(ProductosTienda):
  PromedPrecio = 0
  SumaPrecio = 0 
  for Fila in range(len(ProductosTienda)):
	  SumaPrecio = SumaPrecio + ProductosTienda[Fila][2]
	  PromedPrecio = SumaPrecio / (len(ProductosTienda))
  return round(PromedPrecio,1)

def InventarioPrecio(ProductosTienda):
  ValorInventario = 0.0
  for Fila in range (len(ProductosTienda)):
	  ValorInventario = ValorInventario + (ProductosTienda[Fila][2] * ProductosTienda[Fila][3])
  return round(ValorInventario,1)


# Programa principal:
ProductosTienda=[
[1, "Manzanas", 5000.0, 25],
[2, "Limones", 2300.0, 15],
[3, "Peras", 2700.0, 33],
[4, "Arandanos", 9300.0, 5],
[5, "Tomates", 2100.0, 42],
[6, "Fresas", 4100.0, 3],
[7, "Helado", 4500.0, 41],
[8, "Galletas", 500.0, 8],
[9, "Chocolates", 3500.0, 80],
[10 ,"Jamon", 15000.0, 10]]

Operacion, Producto = LeerDatos()

Respuesta = ""

if Operacion == "BORRAR":
  Flag = ""
  Flag = Borrar(ProductosTienda, Producto)
  print(Flag)
  
elif Operacion == "ACTUALIZAR": 
  Flag = ""
  Flag = Actualizar(ProductosTienda, Producto)
  print(Flag)
  
elif Operacion == "AGREGAR": 
  Flag = "" 
  Flag = Agregar(ProductosTienda, Producto)
  print(Flag)
  

if Flag == 1:  
  print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
elif Flag == 2:
  print("ERROR")
# Out:
# actualizar
# 7 Helado 65000 11
# 2
# ERROR

# %% [markdown]
# # Reto 5

# %% [markdown]
# Enunciado
# Título: Aplicación de gestión de inventarios.
#
# Una tienda vende diferentes productos, usualmente frutas, dulces y algunos tipos de carne. Con el propósito de mejorar el control sobre las ventas y el inventario de la tienda, el gerente decide construir una aplicación que le permita almacenar la información de los productos y realizar algunos cálculos sobre los datos.
#
# En la primera parte del reto se debe construir una base de datos que almacene la información de los productos disponibles en la tienda. La base de datos será representada mediante un diccionario de Python llamado productos que tendrá por llave el código del producto y por valor una lista formada por los atributos: nombre, precio e inventario. La Tabla 1 presenta los productos disponibles a la fecha.
# Tabla 1: Productos disponibles en la tienda
#
#
# Es necesario construir 3 funciones que representen las operaciones de: AGREGAR, ACTUALIZAR y BORRAR los productos disponibles. Se debe implementar una función independiente por cada una de las acciones mencionadas. En este caso, para poder realizar las operaciones de ACTUALIZAR o BORRAR es necesario especificar todos los atributos del producto.
#
# Adicionalmente, se está interesado en analizar los datos de los productos disponibles y conocer: el nombre del producto con el precio mayor; el nombre del producto con el precio menor; el promedio de precios de todos los productos y el valor total del inventario a la fecha. Este último se obtiene multiplicando el precio de cada producto por el inventario disponible y luego sumando todos los resultados. Por ejemplo, al calcular estos 4 valores para los datos disponibles en la Tabla 1 obtendríamos:
#
# Producto precio mayor: Jamon
# Producto precio menor: Galletas
# Promedio de precios: 4900.0
# Valor del inventario: 101410.0

# %%
# 2Final?...
# Funciones:
def LeerDatos():
  Operacion = input()
  Operacion = Operacion.upper()
  Código, Nombre, Precio, Inventario = input().split()
  Código= int(Código)
  Precio = float(Precio)
  Inventario = int(Inventario)
  Producto = [] #(código, nombre, precio,inventario)
  Producto.append(Código)
  Producto.append(Nombre)
  Producto.append(Precio)
  Producto.append(Inventario)
  return Operacion, Producto

def Borrar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor=1
      del ProductosTienda[Fila]
    else:
      Interructor = 0                                                   # c=1 esta. c=0 no esta
  return Interructor

def Actualizar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor=1
      ProductosTienda[Fila][2] = Producto[2]
      ProductosTienda[Fila][3] = Producto[3]
    else:
      Interructor = 0
  return Interructor

def Agregar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor = 0
    else:
      Interructor = 1
      ProductosTienda.append(Producto)
  return Interructor

def MayorPrecio(ProductosTienda):
  FilaDelMayor = 0
  ProductoMayorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2]>FilaDelMayor:
	    FilaDelMayor = ProductosTienda[Fila][2]
	    ProductoMayorPrecio = ProductosTienda[Fila][1]
  return ProductoMayorPrecio

def MenorPrecio(ProductosTienda):
  FilaDelMenor = ProductosTienda[0][2]
  ProductoMenorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2] < FilaDelMenor:
	    FilaDelMenor = ProductosTienda[Fila][2]
	    ProductoMenorPrecio = ProductosTienda[Fila][1]
  return ProductoMenorPrecio

def PromedioPrecio(ProductosTienda):
  PromedPrecio = 0
  SumaPrecio = 0 
  for Fila in range(len(ProductosTienda)):
	  SumaPrecio = SumaPrecio + ProductosTienda[Fila][2]
	  PromedPrecio = SumaPrecio / (len(ProductosTienda))
  return round(PromedPrecio,1)

def InventarioPrecio(ProductosTienda):
  ValorInventario = 0.0
  for Fila in range (len(ProductosTienda)):
	  ValorInventario = ValorInventario + (ProductosTienda[Fila][2] * ProductosTienda[Fila][3])
  return round(ValorInventario,1)


# Programa principal:
ProductosTienda=[
[1, "Manzanas", 5000.0, 25],
[2, "Limones", 2300.0, 15],
[3, "Peras", 2700.0, 33],
[4, "Arandanos", 9300.0, 5],
[5, "Tomates", 2100.0, 42],
[6, "Fresas", 4100.0, 3],
[7, "Helado", 4500.0, 41],
[8, "Galletas", 500.0, 8],
[9, "Chocolates", 3500.0, 80],
[10 ,"Jamon", 15000.0, 10]]

Operacion, Producto = LeerDatos()

if Operacion == "BORRAR":
  Flag = Borrar(ProductosTienda, Producto)

  if Borrar(ProductosTienda, Producto) == 0:
    Respuesta = "ERROR"
  elif Borrar(ProductosTienda, Producto) == 1:
    Respuesta = "HECHO"
    
  
elif Operacion == "ACTUALIZAR": 
  Flag = Actualizar(ProductosTienda, Producto)

  if Actualizar(ProductosTienda, Producto) == 1:
    Respuesta = "HECHO"
  elif Actualizar(ProductosTienda, Producto) == 0:
    Respuesta = "ERROR"
  

elif Operacion == "AGREGAR":  
  Flag = Agregar(ProductosTienda, Producto)
  Flag1 = PromedioPrecio(ProductosTienda)
  Flag2 = InventarioPrecio(ProductosTienda)
  #print(Flag1,Flag2)
  if Agregar(ProductosTienda, Producto) == 0:
    Respuesta = "ERROR"

  elif Agregar(ProductosTienda, Producto) == 1:
    Respuesta = "HECHO"


if Respuesta != "ERROR":  
  print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
else:
  print("ERROR")    
    
"""if Respuesta != "ERROR":
  print("f")
else:
  print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))"""
# Out:
# actualizar
# 7 Helado 65000 11
# ERROR
# 'if Respuesta != "ERROR":\n  print("f")\nelse:\n  print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))'

# %%
# 3Final?...
# Funciones:
def LeerDatos():
  Operacion = input()
  Operacion = Operacion.upper()
  Código, Nombre, Precio, Inventario = input().split()
  Código= int(Código)
  Precio = float(Precio)
  Inventario = int(Inventario)
  Producto = [] #(código, nombre, precio,inventario)
  Producto.append(Código)
  Producto.append(Nombre)
  Producto.append(Precio)
  Producto.append(Inventario)
  return Operacion, Producto

def Borrar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor=1
      del ProductosTienda[Fila]
    else:
      Interructor = 0                                                   # c=1 esta. c=0 no esta
  return Interructor

def Actualizar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor=1
      ProductosTienda[Fila][2] = Producto[2]
      ProductosTienda[Fila][3] = Producto[3]
    else:
      Interructor = 0
  return Interructor

def Agregar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor = 1
    else:
      Interructor = 0
      ProductosTienda.append(Producto)
  return Interructor

def MayorPrecio(ProductosTienda):
  FilaDelMayor = 0
  ProductoMayorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2]>FilaDelMayor:
	    FilaDelMayor = ProductosTienda[Fila][2]
	    ProductoMayorPrecio = ProductosTienda[Fila][1]
  return ProductoMayorPrecio

def MenorPrecio(ProductosTienda):
  FilaDelMenor = ProductosTienda[0][2]
  ProductoMenorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2] < FilaDelMenor:
	    FilaDelMenor = ProductosTienda[Fila][2]
	    ProductoMenorPrecio = ProductosTienda[Fila][1]
  return ProductoMenorPrecio

def PromedioPrecio(ProductosTienda):
  PromedPrecio = 0
  SumaPrecio = 0 
  for Fila in range(len(ProductosTienda)):
	  SumaPrecio = SumaPrecio + ProductosTienda[Fila][2]
	  PromedPrecio = SumaPrecio / (len(ProductosTienda))
  return round(PromedPrecio,1)

def InventarioPrecio(ProductosTienda):
  ValorInventario = 0.0
  for Fila in range (len(ProductosTienda)):
	  ValorInventario = ValorInventario + (ProductosTienda[Fila][2] * ProductosTienda[Fila][3])
  return round(ValorInventario,1)


# Programa principal:
ProductosTienda=[
[1, "Manzanas", 5000.0, 25],
[2, "Limones", 2300.0, 15],
[3, "Peras", 2700.0, 33],
[4, "Arandanos", 9300.0, 5],
[5, "Tomates", 2100.0, 42],
[6, "Fresas", 4100.0, 3],
[7, "Helado", 4500.0, 41],
[8, "Galletas", 500.0, 8],
[9, "Chocolates", 3500.0, 80],
[10 ,"Jamon", 15000.0, 10]]

Operacion, Producto = LeerDatos()

if Operacion == "BORRAR":
  Flag = Borrar(ProductosTienda, Producto)
elif Operacion == "ACTUALIZAR": 
  Flag = Actualizar(ProductosTienda, Producto)
elif Operacion == "AGREGAR":  
  Flag = Agregar(ProductosTienda, Producto)


if Operacion == "BORRAR":
  if Borrar(ProductosTienda, Producto) == 1:
    Respuesta1 = "HECHO"
    print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
  elif Borrar(ProductosTienda, Producto) == 0:
    Respuesta2 = "ERROR"
    print(Respuesta2)
elif Operacion == "ACTUALIZAR": 
  if Actualizar(ProductosTienda, Producto) == 1:
    Respuesta1 = "HECHO"
    print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
  elif Actualizar(ProductosTienda, Producto) == 0:
    Respuesta2 = "ERROR"
    print(Respuesta2)
elif Operacion == "AGREGAR":  
  if Agregar(ProductosTienda, Producto) == 1:
    Respuesta1 = "ERROR"
    print(Respuesta1)
  elif Agregar(ProductosTienda, Producto) == 0:
    Respuesta2 = "HECHO"     
    print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))

# print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
# Out:
# borrar
# 10 Jamon 15000 10
# ERROR

# %%
# 1Final?...
# Funciones:
def LeerDatos():
  Operacion = input()
  Operacion = Operacion.upper()
  Producto = [input().split()] #(código, nombre, precio,inventario)
  print(type(Producto[0]))
  Producto[0]= int(Producto[0])
  Producto[2]= float(Producto[2])
  Producto[3]= int(Producto[0])
  return Operacion, Producto

def Borrar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor=1
      del ProductosTienda[Fila]
    else:
      Interructor = 0                                                   # c=1 esta. c=0 no esta
  return Interructor

def Actualizar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor=1
      ProductosTienda[Fila][2] = Producto[2]
      ProductosTienda[Fila][3] = Producto[3]
    else:
      Interructor = 0
  return Interructor

def Agregar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Interructor = 1
    else:
      Interructor = 0
      ProductosTienda.append(Producto)
  return Interructor

def MayorPrecio(ProductosTienda):
  FilaDelMayor = 0
  ProductoMayorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2]>FilaDelMayor:
	    FilaDelMayor = ProductosTienda[Fila][2]
	    ProductoMayorPrecio = ProductosTienda[Fila][1]
  return ProductoMayorPrecio

def MenorPrecio(ProductosTienda):
  FilaDelMenor = ProductosTienda[0][2]
  ProductoMenorPrecio = ""
  for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2] < FilaDelMenor:
	    FilaDelMenor = ProductosTienda[Fila][2]
	    ProductoMenorPrecio = ProductosTienda[Fila][1]
  return ProductoMenorPrecio

def PromedioPrecio(ProductosTienda):
  PromedPrecio = 0
  SumaPrecio = 0 
  for Fila in range(len(ProductosTienda)):
	  SumaPrecio = SumaPrecio + ProductosTienda[Fila][2]
	  PromedPrecio = SumaPrecio / (len(ProductosTienda))
  return round(PromedPrecio,1)

def InventarioPrecio(ProductosTienda):
  ValorInventario = 0.0
  for Fila in range (len(ProductosTienda)):
	  ValorInventario = ValorInventario + (ProductosTienda[Fila][2] * ProductosTienda[Fila][3])
  return round(ValorInventario,1)


# Programa principal:
ProductosTienda=[
[1, "Manzanas", 5000.0, 25],
[2, "Limones", 2300.0, 15],
[3, "Peras", 2700.0, 33],
[4, "Arandanos", 9300.0, 5],
[5, "Tomates", 2100.0, 42],
[6, "Fresas", 4100.0, 3],
[7, "Helado", 4500.0, 41],
[8, "Galletas", 500.0, 8],
[9, "Chocolates", 3500.0, 80],
[10 ,"Jamon", 15000.0, 10]]

Operacion, Producto = LeerDatos()

if Operacion == "BORRAR":
  Flag = Borrar(ProductosTienda, Producto)

  if Borrar(ProductosTienda, Producto) == 1:
    Respuesta1 = "HECHO"
  elif Borrar(ProductosTienda, Producto) == 0:
    Respuesta2 = "ERROR"
  print(Respuesta2)
elif Operacion == "ACTUALIZAR": 
  Flag = Actualizar(ProductosTienda, Producto)

  if Actualizar(ProductosTienda, Producto) == 1:
    Respuesta1 = "HECHO"
  elif Actualizar(ProductosTienda, Producto) == 0:
    Respuesta2 = "ERROR"
  print(Respuesta2)
elif Operacion == "AGREGAR":  
  Flag = Agregar(ProductosTienda, Producto)

  if Agregar(ProductosTienda, Producto) == 1:
    Respuesta1 = "ERROR"
  elif Agregar(ProductosTienda, Producto) == 0:
    Respuesta2 = "HECHO"
  print(Respuesta1)

if Respuesta != "ERROR":  
  print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
else:
  print("ERROR")
# Out:
# BORRAR
# 14 Maiz 45000 12
# <class 'list'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-81e19283e933> in <module>()
#      85 [10 ,"Jamon", 15000.0, 10]]
#      86
# ---> 87 Operacion, Producto = LeerDatos()
#      88
#      89 if Operacion == "BORRAR":
#
# <ipython-input-53-81e19283e933> in LeerDatos()
#       6   Producto = [input().split()] #(código, nombre, precio,inventario)
#       7   print(type(Producto[0]))
# ----> 8   Producto[0]= int(Producto[0])
#       9   Producto[2]= float(Producto[2])
#      10   Producto[3]= int(Producto[0])
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
def buscarCedula2(ced):
    c=0
    archivo=open("agenda.txt","r")
    datos=archivo.readlines()
    for linea in datos:
        if linea.startswith(ced):
            c=1
            break
    archivo.close()
    return c

def eliminar(ced):
    archivo=open("agenda.txt","r")
    datos=archivo.readlines()
    x=0
    for linea in datos:
        if linea.startswith(ced):
            del datos[x]  # borra cedula y sube la linea
            del datos[x]  # borra telefono
            del datos[x-1] # borra nombre
            break
        x=x+1
    archivo.close()
    archivo=open("agenda.txt","w")
    for linea in datos:
        archivo.write(linea)
    archivo.close()


def adicionar(nom,ced,tel):
    archivo=open("agenda.txt","a")
    archivo.write(nom+"\n")
    archivo.write(ced+"\n")
    archivo.write(tel+"\n")
    archivo.close()   



    
if Operacion == "BORRAR":
  Flag = Borrar(ProductosTienda, Producto)

  if Borrar(ProductosTienda, Producto) == 1:
    Respuesta1 = "HECHO"
  elif Borrar(ProductosTienda, Producto) == 0:
    Respuesta2 = "ERROR"
    print(Respuesta2)
elif Operacion == "ACTUALIZAR": 
  Flag = Actualizar(ProductosTienda, Producto)

  if Actualizar(ProductosTienda, Producto) == 1:
    Respuesta1 = "HECHO"
  elif Actualizar(ProductosTienda, Producto) == 0:
    Respuesta2 = "ERROR"
    print(Respuesta2)
elif Operacion == "AGREGAR":  
  Flag = Agregar(ProductosTienda, Producto)

  if Agregar(ProductosTienda, Producto) == 1:
    Respuesta1 = "ERROR"
  elif Agregar(ProductosTienda, Producto) == 0:
    Respuesta2 = "HECHO"
    print(Respuesta1)
print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))

# %%
# Funciones:
def LeerDatos():
  Operacion = input()
  Producto = [input().split()] #(código, nombre, precio,inventario)
  Producto[0]= int(Producto[0])
  Producto[1]= float(Producto[1])
  Producto[3]= int(Producto[0])
  return Operacion, Producto

def Borrar(ProductosTienda, Producto):
 for Fila in range(len(ProductosTienda)):
  if Producto[0] == ProductosTienda[Fila][0]:
    Respuesta=1
    del ProductosTienda[Fila]
  else:
    Respuesta = "ERROR"                                                   # c=1 esta. c=0 no esta
    return Respuesta
  return 

def Actualizar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Respuesta=1
    #
    else:
      Respuesta = "ERROR"
      return Respuesta
  return

def Agregar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Respuesta = "ERROR" 
      return Respuesta
    else:
      Respuesta=1 
      ProductosTienda.append(Producto)
  return     

def MayorPrecio(ProductosTienda):
	FilaDelMayor = 0
	ProductoMayorPrecio = ""
	for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2]>FilaDelMayor:
	    FilaDelMayor = ProductosTienda[Fila][2]
	    ProductoMayorPrecio = ProductosTienda[Fila][1]
	return ProductoMayorPrecio
	
def MenorPrecio(ProductosTienda):
	FilaDelMenor = ProductosTienda[0][2]
	ProductoMenorPrecio = ""
	for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2] < FilaDelMenor:
	    FilaDelMenor = ProductosTienda[Fila][2]
	    ProductoMenorPrecio = ProductosTienda[Fila][1]
	return ProductoMenorPrecio

def PromedioPrecio(ProductosTienda):
	PromedPrecio = 0
  SumaPrecio = 0 
  for Fila in range(len(ProductosTienda)):
	  SumaPrecio = SumaPrecio + ProductosTienda[Fila][2]
	  PromedPrecio = SumaPrecio / (len(ProductosTienda))
  return round(PromedPrecio,1)

def InventarioPrecio(ProductosTienda):
	ValorInventario = 0.0
	for Fila in range (len(ProductosTienda)):
	  ValorInventario = ValorInventario + (ProductosTienda[Fila][2] * ProductosTienda[Fila][3])
	return round(ValorInventario,1)  

# programa principal:

ProductosTienda=[
[1, "Manzanas", 5000.0, 25],
[2, "Limones", 2300.0, 15],
[3, "Peras", 2700.0, 33],
[4, "Arandanos", 9300.0, 5],
[5, "Tomates", 2100.0, 42],
[6, "Fresas", 4100.0, 3],
[7, "Helado", 4500.0, 41],
[8, "Galletas", 500.0, 8],
[9, "Chocolates", 3500.0, 80],
[10 ,"Jamon", 15000.0, 10]
]

Operacion, Producto = LeerDatos()
if Operacion == "BORRAR":
  Flag = Borrar(ProductosTienda, Producto)
elif Operacion == "ACTUALIZAR": 
  Flag = Actualizar(ProductosTienda, Producto)
elif Operacion == "AGREGAR":  
  Flag = Agregar(ProductosTienda, Producto)

print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))

# %%
ProductosTienda=[
[1, "Manzanas", 5000.0, 25],
[2, "Limones", 2300.0, 15],
[3, "Peras", 2700.0, 33],
[4, "Arandanos", 9300.0, 5]]

def Agregar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Respuesta = "ERROR" 
      return Respuesta
    else:
      Respuesta=1 
      ProductosTienda.append(Producto)

def LeerDatos():
  Producto = [input().split()] #(código, nombre, precio,inventario)
  Producto[0]= int(Producto[0])
  Producto[1]= float(Producto[1])
  Producto[3]= int(Producto[0])
  return Producto      

Producto = LeerDatos()
flag = Agregar(ProductosTienda, Producto)
print(ProductosTienda)
# Out:
# 10 Jamon 15000.0 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-5605262d0a30> in <module>()
#      21   return Producto
#      22
# ---> 23 Producto = LeerDatos()
#      24 flag = Agregar(ProductosTienda, Producto)
#      25 print(ProductosTienda)
#
# <ipython-input-22-5605262d0a30> in LeerDatos()
#      16 def LeerDatos():
#      17   Producto = [input().split()] #(código, nombre, precio,inventario)
# ---> 18   Producto[0]= int(Producto[0])
#      19   Producto[1]= float(Producto[1])
#      20   Producto[3]= int(Producto[0])
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
# Funciones:
def LeerDatos():
  Operacion = input()
  Producto = [input().split()] #(código, nombre, precio,inventario)
  Producto[0]= int(Producto[0])
  Producto[1]= float(Producto[1])
  Producto[3]= int(Producto[0])
  return Operacion, Producto

def Borrar(ProductosTienda, Producto):
 for Fila in range(len(ProductosTienda)):
  if Producto[0] == ProductosTienda[Fila][0]:
    Respuesta=1
    del ProductosTienda[Fila]
  else:
    Respuesta = "ERROR"                                                   # c=1 esta. c=0 no esta
    return Respuesta
  return c

def Actualizar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Respuesta=1
    #
    else:
      Respuesta = "ERROR"
      return Respuesta
  return c

def Agregar(ProductosTienda, Producto):
  for Fila in range(len(ProductosTienda)):
    if Producto[0] == ProductosTienda[Fila][0]:
      Respuesta = "ERROR" 
      return Respuesta
    else:
      Respuesta=1 
      ProductosTienda.append(Producto)
  return     

def MayorPrecio(ProductosTienda):
	FilaDelMayor = 0
	ProductoMayorPrecio = ""
	for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2]>FilaDelMayor:
	    FilaDelMayor = ProductosTienda[Fila][2]
	    ProductoMayorPrecio = ProductosTienda[Fila][1]
	return ProductoMayorPrecio
	
def MenorPrecio(ProductosTienda):
	FilaDelMenor = ProductosTienda[0][2]
	ProductoMenorPrecio = ""
	for Fila in range (len(ProductosTienda)):
	  if ProductosTienda[Fila][2] < FilaDelMenor:
	    FilaDelMenor = ProductosTienda[Fila][2]
	    ProductoMenorPrecio = ProductosTienda[Fila][1]
	return ProductoMenorPrecio

def PromedioPrecio(ProductosTienda):
	SumaPrecio = 0
  PromedPrecio = 0
  for Fila in range(len(ProductosTienda)):
	  SumaPrecio = SumaPrecio + ProductosTienda[Fila][2]
	  PromedPrecio = SumaPrecio / (len(ProductosTienda))
  return round(PromedPrecio,1)

def InventarioPrecio(ProductosTienda):
	ValorInventario = 0.0
	for Fila in range (len(ProductosTienda)):
	  ValorInventario = ValorInventario + (ProductosTienda[Fila][2] * ProductosTienda[Fila][3])
	return round(ValorInventario,1)  

# programa principal:

ProductosTienda=[
[1, "Manzanas", 5000.0, 25],
[2, "Limones", 2300.0, 15],
[3, "Peras", 2700.0, 33],
[4, "Arandanos", 9300.0, 5],
[5, "Tomates", 2100.0, 42],
[6, "Fresas", 4100.0, 3],
[7, "Helado", 4500.0, 41],
[8, "Galletas", 500.0, 8],
[9, "Chocolates", 3500.0, 80],
[10 ,"Jamon", 15000.0, 10]
]

Operacion, Producto = LeerDatos()
if Operacion == "BORRAR":
  Flag = Borrar(ProductosTienda, Producto)
elif Operacion == "ACTUALIZAR": 
  Flag = Actualizar(ProductosTienda, Producto)
elif Operacion == "AGREGAR":  
  Flag = Agregar(ProductosTienda, Producto)

print(MayorPrecio(ProductosTienda), MenorPrecio(ProductosTienda)), PromedioPrecio(ProductosTienda), InventarioPrecio(ProductosTienda))
# Out:
#   File "<ipython-input-19-46e8ca81d2e0>", line 60
#     PromedPrecio = 0
#                     ^
# IndentationError: unindent does not match any outer indentation level
