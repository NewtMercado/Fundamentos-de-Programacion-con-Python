# %%
"# Programa 3: almacena diferentes datos ingresados por teclado a un mismo tiempo (tipo 2)
Nombre, apellido, edad, sexo = input("ingrese su nombre, apellido, edad y sexo (cada palabra separada por espacio): ") 
  # almacena mediante variables los datos ingresados por el usuario
"print("hola",sexo, Nombre, apellido, "de", edad)"
  # imprime los diferentes datos almacenados

# %%
print("ingrese Numero 1: ")
Numero1= float(input())
print("ingrese Numero 2: ")
Numero2= float(input())
print("ingrese Numero 3: ")
Numero3= float(input())

if Numero1 < Numero2 and Numero1 < Numero3:
  print("el numero",Numero1,"es menor que", Numero2, "y", Numero3 )
elif  Numero1 > Numero2 and Numero1 < Numero3:
  print("el numero",Numero1,"es mayor que", Numero2, "y es menor que", Numero3 )

elif Numero1 > Numero2 and Numero1 > Numero3:
  print("el numero",Numero1,"es mayor que", Numero2, "y es mayor que", Numero3 )

elif Numero2 > Numero1 and Numero2 > Numero3:
  print("el numero",Numero1,"es mayor que", Numero2, "y es mayor que", Numero3 )

elif Color=="azul":
  print("Usted tendra un descuento del 50%, debe pagar:")
  Descuento = ValorCompra * (50/100)
  ValorTotal = ValorCompra - Descuento
  print(ValorTotal)
elif Color=="roja":
  print("Usted tendra un descuento del 50%, debe pagar:")
  Descuento = ValorCompra * (100/100)
  ValorTotal = ValorCompra - Descuento
  print(ValorTotal)
else:
  print("no tengo informacion de ese color")
